# %% [markdown]
# # 第 9 周 Day 7：论文对比与周项目验收 — Notebook 作业
#
# [← Week 09 / Day 06](day-06.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-09/day-07.md) · [Goal 进度](../../PROGRESS.md) · [Week 10 / Day 01 →](../week-10/day-01.ipynb)
#
# > 状态：**未提交**。直接编辑各个 Markdown/Code 单元格；“教练验收区”不要预填。

# %% [markdown]
# ## Goal
#
# 预计：**150–210 分钟**。
#
# - 把 RT-1、RT-2、OXE/RT-X 的关键决策放进同一比较框架。
# - 完成跨本体 mock 数据接入审计。
# - 通过概念测验、代码复跑和失败复盘。
#
# ### 我的目标复述
#
# 【双击此 Markdown 单元格，用自己的话填写今日目标及其在 VLA 中的作用。】

# %% [markdown]
# ## Setup
#
# | 字段 | 我的记录 |
# |---|---|
# | 实际投入时间 | 【填写】 |
# | 完成日期 | 【填写】 |
# | Python / PyTorch | 【填写；纯理论日写“不适用”】 |
# | CPU / GPU / 仿真器 | 【填写】 |
# | 资源等级 | 【L0 / L1 / L2】 |
# | 产物路径 | 【填写】 |
#
# 生成时环境检查（2026-09-01）：当前可见 Python 未检测到 Jupyter、ipykernel、nbformat、PyTorch 或 NumPy。本 Notebook 已做结构验证，但在该环境中尚未执行。

# %%
# 可选：Notebook 环境可用后运行此单元，记录基础环境。
import platform
import sys

print("python:", sys.version)
print("platform:", platform.platform())

# %% [markdown]
# ## Context：知识点及其在 VLA 中的作用
#
# 论文阅读只有转化为数据、模型和评估决策才真正服务 VLA 项目；本日把本周知识固化为第 10 周可直接使用的 adapter 契约。

# %% [markdown]
# ## Concepts：概念、公式、形状与数据流
#
# - 比较维度至少包括：输入、语言融合、动作表示、数据来源、跨本体方式、训练目标、评估泛化、算力成本和主要风险。
# - 周项目证据链：`原始 mock → schema 校验 → canonical action → normalization → round-trip → report`。
# - 论文声称、你的推断和本地实测必须分栏记录，避免把二手理解写成事实。

# %% [markdown]
# ## Learning Steps
#
# 1. 闭卷完成 4 道周测后再查资料修正。
# 2. 复跑 inspector 的合法与三个损坏样例。
# 3. 完成论文比较矩阵，并为最终项目选出保留/不采用的设计。
# 4. 写失败复盘：最危险的两类数据错误、当前检测覆盖和遗留风险。

# %% [markdown]
# ## Steps：必做作业
#
# ### 课程题目
#
# - 提交 `w09_paper_matrix.md` 与 `w09_week_project.md`。
# - 附运行命令、退出码、关键输出和产物路径。
# - 给第 10 周写一份 `openvla_adapter_handoff.md`，列出 processor 前后的字段契约。
#
# 下面每道题都有独立作答单元。文字、表格、公式或 Mermaid 写在 Markdown 单元；可运行代码写在后面的 Code 单元。

# %% [markdown]
# ### 第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 可运行代码 / 实验区
#
# 纯理论日可以保留为空；代码日请将实现拆成短小单元，并保留关键输出。

# %%
# 在此编写或运行当天代码。
# 建议先写清输入 shape、dtype、设备和随机种子。

# %% [markdown]
# ## Checks：输入、预期输出与验证
#
# | 项目 | 内容 |
# |---|---|
# | 输入 | Day 1–6 全部产物；无网络/无 GPU 即可。 |
# | 预期输出 | 矩阵至少 9 个比较维度；项目能接受合法样例、拒绝 3 类坏样例；handoff 明确 image、instruction、action、dataset key 与 stats。 |
# | 验证方法 | 随机抽一个 episode 手工核对检查器结论。；删除一个统计 key，确认系统显式失败而非静默选默认值。；周测达到 80%，关键概念无误。 |
#
# 预期输出只有在实际运行并保留证据后才能改写为“实测通过”。
#
# ### 我的验证记录
#
# | 检查项 | 实际结果 | 是否符合 | 证据 |
# |---|---|---|---|
# | 输入 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | 输出 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | dtype、范围和单位 | 【填写】 | 【填写】 | 【填写】 |
# | 正向测试 | 【填写】 | 【填写】 | 【填写】 |
# | 负向测试 / 错误注入 | 【填写】 | 【填写】 | 【填写】 |
# | 指标分子 / 分母 / seed | 【填写】 | 【填写】 | 【填写】 |
#
# > 尚未运行的内容必须标为“预期结果”，不能作为实际证据。

# %%
# 在此编写 shape、dtype、数值范围、断言或负向测试。

# %% [markdown]
# ## Evidence：提交与复现证据
#
# ```markdown
# # W09D07 提交
#
# - 实际用时：写明分钟数
# - 使用环境：写明 Python/库版本；未运行写“仅静态分析”
#
# ## 概念与推导
# 写出关键定义、公式推导和张量形状。
#
# ## 作业实现
# 列出文件路径、核心代码说明与设计选择。
#
# ## 验证证据
# 粘贴命令、退出码、关键输出；未执行的结果逐项标为“预期”。
#
# ## 错误注入与修正
# 记录至少一个失败、定位证据与修复后结果。
#
# ## 自测答案
# 逐题回答本页自测题。
# ```
#
# ### 我的证据
#
# - 代码路径：【填写】
# - 配置路径：【填写】
# - 数据 / checkpoint / commit 或哈希：【填写】
# - 实际命令：【填写】
# - 退出码：【填写】
# - 关键输出：【填写】
# - 结果说明了什么：【填写】
# - 结果没有说明什么：【填写】
# - 失败现象与定位证据：【填写】
#
# ### VLA 约束
#
# | 约束 | 我的定义 |
# |---|---|
# | 图像布局、颜色顺序和范围 | 【填写】 |
# | 文本 token、padding 与 mask | 【填写】 |
# | 机器人状态各维含义 | 【填写】 |
# | 坐标系、长度和角度单位 | 【填写】 |
# | 动作空间及逐维定义 | 【填写】 |
# | observation/action 时间对齐 | 【填写】 |
# | 控制频率 / action chunk | 【填写】 |
# | 归一化及统计量来源 | 【填写】 |
# | 随机种子与数据划分 | 【填写】 |

# %% [markdown]
# ## Self-check：课程自测
#
# 1. 本周哪项设计最能防止静默数据错误？
# 2. 跨本体训练最难统一的是什么？
# 3. 进入 OpenVLA 前仍有哪些未知项？
#
# ---

# %% [markdown]
# ### 自测第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ## Help：排查、最低完成线与提高
#
# ### 常见错误
#
# - 比较矩阵只有论文摘要，没有工程选择。
# - 修复坏样例时同时改了多个变量，无法定位原因。
# - 把下一周尚未运行的 OpenVLA 流程写成已跑通。
# - 若输出与预期不符，先打印 episode/step 索引、shape、dtype、单位和 dataset key，再检查模型。
# - 不得把论文中的报告结果或本页“预期输出”写成本地实测。
#
# ### 最低完成线
#
# 完成周测、5 维论文矩阵、一个合法/两个非法复跑和 handoff 契约。 最低完成线仍须提交证据，且只能获得“最低线通过”，后续需补齐完整产物。
#
# ### 可选提高
#
# 录制 3 分钟讲解，按矩阵解释为何最终项目采用某种动作表示。

# %% [markdown]
# ## Rubric
#
# | 评分项 | 分值 | 得分条件 |
# |---|---:|---|
# | 概念、公式与形状 | 20 | 定义准确，变量、单位和 shape 可追踪 |
# | 实现或结构化产物 | 25 | 文件完整，输入输出契约明确 |
# | 验证证据 | 25 | 有命令/手算、断言、实际输出或诚实的“预期”标记 |
# | VLA 场景分析 | 20 | 能联系闭环、数据或动作风险，而非复述定义 |
# | 复盘与自测 | 10 | 解释失败原因并正确回答自测 |
# | **总分** | **100** | **80 分通过** |
#
# 硬门槛：任何进度不能仅凭口头“完成”勾选；缺少运行证据时必须写“预期”，且项目暂不算复跑通过。
#
# ### 提交前检查
#
# - [ ] 已逐项完成必做作业；
# - [ ] 已区分实际结果与预期结果；
# - [ ] 已保留代码输出、日志、表格或推理证据；
# - [ ] 已记录适用的 shape、坐标系、单位、动作和时间约定；
# - [ ] 已完成验证或明确写出无法执行的原因；
# - [ ] 已回答全部自测题；
# - [ ] 已记录仍不确定的点或失败案例。

# %% [markdown]
# ## Coach Review（学习者请勿填写）
#
# | 字段 | 验收结果 |
# |---|---|
# | 证据完整性 | 待验收 |
# | Rubric 得分 | /100 |
# | 门槛项 | 待验收 |
# | 当天状态 | 未提交 |
# | 具体缺口 |  |
# | 最小补救任务 |  |
# | 复验结果 |  |
# | 下一课程 |  |

# %% [markdown]
# ## Next Steps
#
# 完成后保存 Notebook，并把路径发到学习对话：
#
# `docs/vla-learning/notebooks/week-09/day-07.ipynb`
#
# 教练验收通过后才会更新 `PROGRESS.md`。
#
# [← Week 09 / Day 06](day-06.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-09/day-07.md) · [Week 10 / Day 01 →](../week-10/day-01.ipynb)
