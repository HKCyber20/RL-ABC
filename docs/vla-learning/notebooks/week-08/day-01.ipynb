# %% [markdown]
# # 第 8 周 Day 1：总体架构与接口冻结 — Notebook 作业
#
# [← Week 07 / Day 07](../week-07/day-07.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-08/day-01.md) · [Goal 进度](../../PROGRESS.md) · [Week 08 / Day 02 →](day-02.ipynb)
#
# > 状态：**未提交**。直接编辑各个 Markdown/Code 单元格；“教练验收区”不要预填。

# %% [markdown]
# ## Goal
#
# 预计 120 分钟。画出并冻结最小 VLA 的模块、数据类型和 shape 接口，让一个 synthetic batch 从原始输入通过所有编码器、融合层和动作头。
#
# ### 我的目标复述
#
# 【双击此 Markdown 单元格，用自己的话填写今日目标及其在 VLA 中的作用。】

# %% [markdown]
# ## Setup
#
# | 字段 | 我的记录 |
# |---|---|
# | 实际投入时间 | 【填写】 |
# | 完成日期 | 【填写】 |
# | Python / PyTorch | 【填写；纯理论日写“不适用”】 |
# | CPU / GPU / 仿真器 | 【填写】 |
# | 资源等级 | 【L0 / L1 / L2】 |
# | 产物路径 | 【填写】 |
#
# 生成时环境检查（2026-09-01）：当前可见 Python 未检测到 Jupyter、ipykernel、nbformat、PyTorch 或 NumPy。本 Notebook 已做结构验证，但在该环境中尚未执行。

# %%
# 可选：Notebook 环境可用后运行此单元，记录基础环境。
import platform
import sys

print("python:", sys.version)
print("platform:", platform.platform())

# %% [markdown]
# ## Context：知识点及其在 VLA 中的作用
#
# 端到端集成最常见的错误并非模型公式，而是训练/推理预处理不同、mask 方向相反、统计缺失或动作定义漂移。接口冻结把这些隐性假设变为自动检查的合同。

# %% [markdown]
# ## Concepts：概念、公式、形状与数据流
#
# 建议模型边界：
#
# ```text
# rgb         [B,3,H,W] float32
# token_ids   [B,L]     int64
# text_mask   [B,L]     bool
# state       [B,d_s]   float32
#              ↓ encoders/fusion
# action_pred [B,H_a,d_a] float32
# ```
#
# 单步动作是 `H_a=1` 的特例。定义 `policy(batch) → normalized_action_chunk`；环境 adapter 负责反归一化、坐标映射、边界检查和 step。checkpoint 必须绑定 `schema_version/tokenizer_hash/action_stats/config`。

# %% [markdown]
# ## Learning Steps
#
# 1. 从第 5–7 周复制“契约结论”，不要重写另一套预处理。
# 2. 画环境、dataset、collate、policy、action adapter、success checker 的方向图。
# 3. 为每个模块写输入输出 key、shape、dtype、单位、设备和所有者。
# 4. 定义 `VLAPolicy.forward` 与 `predict_action`；后者必须切 eval/no_grad，但不做环境私有变换。
# 5. 用 `B=2` synthetic batch 完成 forward，加入至少 10 个断言。
# 6. 故意破坏 mask、shape、schema_version，确认错误在边界被捕获。

# %% [markdown]
# ## Steps：必做作业
#
# ### 课程题目
#
# - 提交总体架构图和模块契约表。
# - 实现端到端 smoke test，打印各中间张量 shape/有限值/设备。
# - 实现三类负向测试：文本 mask 错、state 维错、checkpoint/schema 不匹配。
#
# 下面每道题都有独立作答单元。文字、表格、公式或 Mermaid 写在 Markdown 单元；可运行代码写在后面的 Code 单元。

# %% [markdown]
# ### 第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 可运行代码 / 实验区
#
# 纯理论日可以保留为空；代码日请将实现拆成短小单元，并保留关键输出。

# %%
# 在此编写或运行当天代码。
# 建议先写清输入 shape、dtype、设备和随机种子。

# %% [markdown]
# ## Checks：输入、预期输出与验证
#
# 输入：两张任务相关 synthetic RGB、两条 tokenized 指令、两个 state；动作维使用已冻结 schema，chunk 暂设 `H_a=1`。
#
# 预期输出：动作 `[2,1,d_a]` 有限；所有模块 batch 一致；三种坏输入给出可定位异常。均为预期结果。
#
# 验证：模型 `eval()` 两次输出一致；batch 重排后输出同步重排；checkpoint metadata 与运行时 config 比较；动作输出不能在模型内默默 clip。
#
# ### 我的验证记录
#
# | 检查项 | 实际结果 | 是否符合 | 证据 |
# |---|---|---|---|
# | 输入 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | 输出 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | dtype、范围和单位 | 【填写】 | 【填写】 | 【填写】 |
# | 正向测试 | 【填写】 | 【填写】 | 【填写】 |
# | 负向测试 / 错误注入 | 【填写】 | 【填写】 | 【填写】 |
# | 指标分子 / 分母 / seed | 【填写】 | 【填写】 | 【填写】 |
#
# > 尚未运行的内容必须标为“预期结果”，不能作为实际证据。

# %%
# 在此编写 shape、dtype、数值范围、断言或负向测试。

# %% [markdown]
# ## Evidence：提交与复现证据
#
# ```markdown
# # W8D1 提交
# - 实际用时：
# ## 端到端架构图
# ## 模块契约表
# ## 10 项 shape/dtype/metadata 断言
# ## Smoke test 命令与日志
# ## 三个负向测试
# ## 自测答案
# ```
#
# ### 我的证据
#
# - 代码路径：【填写】
# - 配置路径：【填写】
# - 数据 / checkpoint / commit 或哈希：【填写】
# - 实际命令：【填写】
# - 退出码：【填写】
# - 关键输出：【填写】
# - 结果说明了什么：【填写】
# - 结果没有说明什么：【填写】
# - 失败现象与定位证据：【填写】
#
# ### VLA 约束
#
# | 约束 | 我的定义 |
# |---|---|
# | 图像布局、颜色顺序和范围 | 【填写】 |
# | 文本 token、padding 与 mask | 【填写】 |
# | 机器人状态各维含义 | 【填写】 |
# | 坐标系、长度和角度单位 | 【填写】 |
# | 动作空间及逐维定义 | 【填写】 |
# | observation/action 时间对齐 | 【填写】 |
# | 控制频率 / action chunk | 【填写】 |
# | 归一化及统计量来源 | 【填写】 |
# | 随机种子与数据划分 | 【填写】 |

# %% [markdown]
# ## Self-check：课程自测
#
# 1. 哪些变换属于 dataset，哪些属于 environment adapter？
# 2. 为什么 action 保留 chunk 维更稳妥？
# 3. tokenizer hash 为何要进入 checkpoint？
# 4. 为什么模型内部不应默默 clip 物理动作？

# %% [markdown]
# ### 自测第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 4 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ## Help：排查、最低完成线与提高
#
# ### 常见错误
#
# | 错误 | 排查 |
# |---|---|
# | `[B,d_a]` 与 `[B,1,d_a]` 混用 | 契约固定保留 chunk 维 |
# | mask 在不同库语义相反 | adapter 边界显式转换并做已知小例 |
# | model 内外重复归一化 | 为 raw/normalized 命名并只指定一个所有者 |
# | checkpoint 加载“成功”但词表不同 | 比较 tokenizer hash 与 schema version |
#
# ### 最低完成线
#
# CPU synthetic batch 跑通 image/text/state → `[2,1,d_a]`，完成 10 个断言和一个 schema mismatch 负向测试。
#
# ### 可选提高
#
# 使用 dataclass/TypedDict 表达 batch；导出 shape trace；统计每个模块参数量和延迟。

# %% [markdown]
# ## Rubric
#
# - 架构覆盖数据到环境闭环：20 分。
# - 模块契约六要素明确：20 分。
# - 十项断言和 smoke test：25 分。
# - 三种负向测试：20 分。
# - 复现元数据与自测：15 分。
#
# 总分 100，80 分通过；训练与推理预处理责任不明、动作 shape/坐标不明或 schema 不匹配仍静默运行时不通过。
#
# ### 提交前检查
#
# - [ ] 已逐项完成必做作业；
# - [ ] 已区分实际结果与预期结果；
# - [ ] 已保留代码输出、日志、表格或推理证据；
# - [ ] 已记录适用的 shape、坐标系、单位、动作和时间约定；
# - [ ] 已完成验证或明确写出无法执行的原因；
# - [ ] 已回答全部自测题；
# - [ ] 已记录仍不确定的点或失败案例。

# %% [markdown]
# ## Coach Review（学习者请勿填写）
#
# | 字段 | 验收结果 |
# |---|---|
# | 证据完整性 | 待验收 |
# | Rubric 得分 | /100 |
# | 门槛项 | 待验收 |
# | 当天状态 | 未提交 |
# | 具体缺口 |  |
# | 最小补救任务 |  |
# | 复验结果 |  |
# | 下一课程 |  |

# %% [markdown]
# ## Next Steps
#
# 完成后保存 Notebook，并把路径发到学习对话：
#
# `docs/vla-learning/notebooks/week-08/day-01.ipynb`
#
# 教练验收通过后才会更新 `PROGRESS.md`。
#
# [← Week 07 / Day 07](../week-07/day-07.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-08/day-01.md) · [Week 08 / Day 02 →](day-02.ipynb)
