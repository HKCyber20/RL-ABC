# %% [markdown]
# # 第 11 周 Day 6：失败 taxonomy 与诊断证据链 — Notebook 作业
#
# [← Week 11 / Day 05](day-05.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-11/day-06.md) · [Goal 进度](../../PROGRESS.md) · [Week 11 / Day 07 →](day-07.ipynb)
#
# > 状态：**未提交**。直接编辑各个 Markdown/Code 单元格；“教练验收区”不要预填。

# %% [markdown]
# ## Goal
#
# 预计：**130–180 分钟**。
#
# - 建立互斥主因、可选次因的失败分类。
# - 把失败定位到感知、语言、接近、抓取、运输、放置、终止或系统层。
# - 用可观察证据而非猜测标注根因。
#
# ### 我的目标复述
#
# 【双击此 Markdown 单元格，用自己的话填写今日目标及其在 VLA 中的作用。】

# %% [markdown]
# ## Setup
#
# | 字段 | 我的记录 |
# |---|---|
# | 实际投入时间 | 【填写】 |
# | 完成日期 | 【填写】 |
# | Python / PyTorch | 【填写；纯理论日写“不适用”】 |
# | CPU / GPU / 仿真器 | 【填写】 |
# | 资源等级 | 【L0 / L1 / L2】 |
# | 产物路径 | 【填写】 |
#
# 生成时环境检查（2026-09-01）：当前可见 Python 未检测到 Jupyter、ipykernel、nbformat、PyTorch 或 NumPy。本 Notebook 已做结构验证，但在该环境中尚未执行。

# %%
# 可选：Notebook 环境可用后运行此单元，记录基础环境。
import platform
import sys

print("python:", sys.version)
print("platform:", platform.platform())

# %% [markdown]
# ## Context：知识点及其在 VLA 中的作用
#
# 成功率告诉你坏了多少，taxonomy 告诉你先修哪里；阶段化失败分析还能区分模型、数据、controller 与仿真异常。

# %% [markdown]
# ## Concepts：概念、公式、形状与数据流
#
# - 建议主类：DATA/SYSTEM、PERCEPTION、LANGUAGE_GROUNDING、APPROACH、GRASP、TRANSPORT、PLACE、TERMINATION、SAFETY；每类有判定规则和所需证据。
# - 主因取最早导致任务不可恢复的事件；后续连锁问题记为 secondary，避免一个 episode 重复计数使总和超过分母。
# - 证据字段：关键帧/step、目标位置、预测动作、gripper、contact、termination、日志错误；无法判断标 UNKNOWN 而非强猜。

# %% [markdown]
# ## Learning Steps
#
# 1. 写 failure_taxonomy.yaml，给每类定义、包含/排除和例子。
# 2. 选 10 个失败 episode 独立标注后复查。
# 3. 画阶段漏斗：进入阶段数→通过数。
# 4. 对前三类失败提出可检验而非泛泛的改进假设。

# %% [markdown]
# ## Steps：必做作业
#
# ### 课程题目
#
# - 提交 taxonomy、标注表和 failure_analysis.md。
# - 至少包含一个 UNKNOWN、一个系统失败和一个连锁失败示例。
# - 验证主因计数之和等于任务失败 episode 数。
#
# 下面每道题都有独立作答单元。文字、表格、公式或 Mermaid 写在 Markdown 单元；可运行代码写在后面的 Code 单元。

# %% [markdown]
# ### 第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 可运行代码 / 实验区
#
# 纯理论日可以保留为空；代码日请将实现拆成短小单元，并保留关键输出。

# %%
# 在此编写或运行当天代码。
# 建议先写清输入 shape、dtype、设备和随机种子。

# %% [markdown]
# ## Checks：输入、预期输出与验证
#
# | 项目 | 内容 |
# |---|---|
# | 输入 | 本周 actual 或 mock rollout records、关键帧/结构化 trace；mock 只验分析管线。 |
# | 预期输出 | 每个失败有唯一 primary、零或多个 secondary、证据引用和置信度；阶段漏斗分母清楚。 |
# | 验证方法 | 两天后盲重标 5 条并比较一致性。；检查 primary 总和。；随机抽 3 条从报告回到原 episode。 |
#
# 若未运行真实仿真，所有 mock 数字必须显式标为“仅验证分析管线”。
#
# ### 我的验证记录
#
# | 检查项 | 实际结果 | 是否符合 | 证据 |
# |---|---|---|---|
# | 输入 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | 输出 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | dtype、范围和单位 | 【填写】 | 【填写】 | 【填写】 |
# | 正向测试 | 【填写】 | 【填写】 | 【填写】 |
# | 负向测试 / 错误注入 | 【填写】 | 【填写】 | 【填写】 |
# | 指标分子 / 分母 / seed | 【填写】 | 【填写】 | 【填写】 |
#
# > 尚未运行的内容必须标为“预期结果”，不能作为实际证据。

# %%
# 在此编写 shape、dtype、数值范围、断言或负向测试。

# %% [markdown]
# ## Evidence：提交与复现证据
#
# ```markdown
# # W11D06 提交
#
# - 实际用时：记录分钟数
# - 数据证据：实际 rollout / 历史日志 / mock 分析管线（如实选择）
# - checkpoint、config hash、seed：逐项记录，未知则说明
#
# ## 协议与公式
# 写成功判据、split、分母、公式和假设。
#
# ## 产物与数据
# 列出脚本、manifest、报告或图表路径。
#
# ## 验证证据
# 粘贴命令、退出码、关键输出和重算结果；未执行写“预期”。
#
# ## 失败与限制
# 记录错误注入、混杂变量、限制和补救。
#
# ## 自测答案
# 逐题作答。
# ```
#
# ### 我的证据
#
# - 代码路径：【填写】
# - 配置路径：【填写】
# - 数据 / checkpoint / commit 或哈希：【填写】
# - 实际命令：【填写】
# - 退出码：【填写】
# - 关键输出：【填写】
# - 结果说明了什么：【填写】
# - 结果没有说明什么：【填写】
# - 失败现象与定位证据：【填写】
#
# ### VLA 约束
#
# | 约束 | 我的定义 |
# |---|---|
# | 图像布局、颜色顺序和范围 | 【填写】 |
# | 文本 token、padding 与 mask | 【填写】 |
# | 机器人状态各维含义 | 【填写】 |
# | 坐标系、长度和角度单位 | 【填写】 |
# | 动作空间及逐维定义 | 【填写】 |
# | observation/action 时间对齐 | 【填写】 |
# | 控制频率 / action chunk | 【填写】 |
# | 归一化及统计量来源 | 【填写】 |
# | 随机种子与数据划分 | 【填写】 |

# %% [markdown]
# ## Self-check：课程自测
#
# 1. 主因为何取最早不可恢复事件？
# 2. UNKNOWN 有何价值？
# 3. 阶段漏斗怎样指导数据采集？
#
# ---

# %% [markdown]
# ### 自测第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ## Help：排查、最低完成线与提高
#
# ### 常见错误
#
# - 抓取前识别错却标为抓取失败。
# - 超时总被标 termination，忽略更早停滞。
# - 无证据也强行细分。
# - 先检查 manifest 行数、唯一 episode id、seed/condition 分布、缺失值和分母，再解释模型。
# - 不得将 mock 记录、预期 CI 或未运行的 rollout 写成真实性能。
#
# ### 最低完成线
#
# 6 类 taxonomy、10 条记录、primary 计数校验。 最低线仍需固定协议并提交可复核证据。
#
# ### 可选提高
#
# 让另一人或第二次盲标，计算简单一致率/Cohen's kappa。

# %% [markdown]
# ## Rubric
#
# | 评分项 | 分值 | 得分条件 |
# |---|---:|---|
# | 协议、公式与统计 | 20 | split、分母、假设和公式准确 |
# | 代码/数据/报告产物 | 25 | schema 完整，结果可回溯 episode |
# | 验证与重算证据 | 25 | 有命令、输出、边界测试或人工复核 |
# | 泛化与失败分析 | 20 | 控制混杂，区分观察/推断/假设 |
# | 复盘与自测 | 10 | 诚实说明限制并答对自测 |
# | **总分** | **100** | **80 分通过** |
#
# 硬门槛：只凭最终画面猜根因、主类重复计数，或系统 crash 算模型任务失败却未区分，不得通过。
#
# ### 提交前检查
#
# - [ ] 已逐项完成必做作业；
# - [ ] 已区分实际结果与预期结果；
# - [ ] 已保留代码输出、日志、表格或推理证据；
# - [ ] 已记录适用的 shape、坐标系、单位、动作和时间约定；
# - [ ] 已完成验证或明确写出无法执行的原因；
# - [ ] 已回答全部自测题；
# - [ ] 已记录仍不确定的点或失败案例。

# %% [markdown]
# ## Coach Review（学习者请勿填写）
#
# | 字段 | 验收结果 |
# |---|---|
# | 证据完整性 | 待验收 |
# | Rubric 得分 | /100 |
# | 门槛项 | 待验收 |
# | 当天状态 | 未提交 |
# | 具体缺口 |  |
# | 最小补救任务 |  |
# | 复验结果 |  |
# | 下一课程 |  |

# %% [markdown]
# ## Next Steps
#
# 完成后保存 Notebook，并把路径发到学习对话：
#
# `docs/vla-learning/notebooks/week-11/day-06.ipynb`
#
# 教练验收通过后才会更新 `PROGRESS.md`。
#
# [← Week 11 / Day 05](day-05.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-11/day-06.md) · [Week 11 / Day 07 →](day-07.ipynb)
