# %% [markdown]
# # 第 12 周 Day 7：答辩、总验收与后续路线 — Notebook 作业
#
# [← Week 12 / Day 06](day-06.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-12/day-07.md) · [Goal 进度](../../PROGRESS.md) · [Notebook 总览 →](../README.md)
#
# > 状态：**未提交**。直接编辑各个 Markdown/Code 单元格；“教练验收区”不要预填。

# %% [markdown]
# ## Goal
#
# 预计：**180–260 分钟**。
#
# - 完成 12 周总 Goal 的证据审计。
# - 进行架构、数据、动作、评估和失败分析答辩。
# - 形成未通过项的最小补救或下一阶段研究路线。
#
# ### 我的目标复述
#
# 【双击此 Markdown 单元格，用自己的话填写今日目标及其在 VLA 中的作用。】

# %% [markdown]
# ## Setup
#
# | 字段 | 我的记录 |
# |---|---|
# | 实际投入时间 | 【填写】 |
# | 完成日期 | 【填写】 |
# | Python / PyTorch | 【填写；纯理论日写“不适用”】 |
# | CPU / GPU / 仿真器 | 【填写】 |
# | 资源等级 | 【L0 / L1 / L2】 |
# | 产物路径 | 【填写】 |
#
# 生成时环境检查（2026-09-01）：当前可见 Python 未检测到 Jupyter、ipykernel、nbformat、PyTorch 或 NumPy。本 Notebook 已做结构验证，但在该环境中尚未执行。

# %%
# 可选：Notebook 环境可用后运行此单元，记录基础环境。
import platform
import sys

print("python:", sys.version)
print("platform:", platform.platform())

# %% [markdown]
# ## Context：知识点及其在 VLA 中的作用
#
# 最后一天不增加新功能，而是证明你能独立解释、运行、审计并复现整个 VLA 项目。

# %% [markdown]
# ## Concepts：概念、公式、形状与数据流
#
# - 总证据链：`spec → code/env → data/card/stats → training/checkpoint → closed-loop manifest → metrics/CI → failures/ablation → report/demo`。
# - 答辩评分覆盖概念 15、数据 20、动作/闭环 20、实验统计 20、OpenVLA 15、复现与诚实边界 10。
# - 验收不等于高成功率；低性能但协议正确、证据完整且失败诊断扎实可以通过，伪造或不可追踪则不能。

# %% [markdown]
# ## Learning Steps
#
# 1. 运行最终 artifact audit，检查缺失文件、hash、链接和 mock/real 标签。
# 2. 从随机 episode 开始，现场追踪输入到动作再到结果表。
# 3. 闭卷回答 12 道答辩题并做 8 分钟项目讲解。
# 4. 按 rubric 标记 PASS/REMEDIATION，不通过项生成最小补救实验。

# %% [markdown]
# ## Steps：必做作业
#
# ### 课程题目
#
# - 提交 FINAL_ACCEPTANCE.md、答辩问答和最终 artifact tree。
# - 实际复跑最小命令链：validate→train/load→closed-loop eval→report。
# - 写后续 4 周路线，只基于已发现瓶颈，不扩张到无关方向。
#
# 下面每道题都有独立作答单元。文字、表格、公式或 Mermaid 写在 Markdown 单元；可运行代码写在后面的 Code 单元。

# %% [markdown]
# ### 第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 可运行代码 / 实验区
#
# 纯理论日可以保留为空；代码日请将实现拆成短小单元，并保留关键输出。

# %%
# 在此编写或运行当天代码。
# 建议先写清输入 shape、dtype、设备和随机种子。

# %% [markdown]
# ## Checks：输入、预期输出与验证
#
# | 项目 | 内容 |
# |---|---|
# | 输入 | 完整课程产物和 Day 6 报告。 |
# | 预期输出 | 所有核心证据可打开/复跑；总分≥80；五项最终能力各有直接证据；遗留问题有 owner/命令/通过标准。 |
# | 验证方法 | 随机抽 5 个报告数字回溯。；换一个 seed 运行闭环。；现场解释 OpenVLA real/mock 证据边界与动作反归一化。 |
#
# 本周“预期”不能替代最终核心闭环实测；需要大模型/GPU 的 OpenVLA 部分可用明确标注的 CPU/mock dry-run。
#
# ### 我的验证记录
#
# | 检查项 | 实际结果 | 是否符合 | 证据 |
# |---|---|---|---|
# | 输入 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | 输出 shape / schema | 【填写】 | 【填写】 | 【填写】 |
# | dtype、范围和单位 | 【填写】 | 【填写】 | 【填写】 |
# | 正向测试 | 【填写】 | 【填写】 | 【填写】 |
# | 负向测试 / 错误注入 | 【填写】 | 【填写】 | 【填写】 |
# | 指标分子 / 分母 / seed | 【填写】 | 【填写】 | 【填写】 |
#
# > 尚未运行的内容必须标为“预期结果”，不能作为实际证据。

# %%
# 在此编写 shape、dtype、数值范围、断言或负向测试。

# %% [markdown]
# ## Evidence：提交与复现证据
#
# ```markdown
# # W12D07 提交
#
# - 实际用时：记录分钟数
# - run/result id：记录可追踪标识
# - 证据等级：真实轻量/完整仿真、真实 OpenVLA、OpenVLA mock dry-run（逐项说明）
#
# ## 冻结合同与设计
# 记录 spec/config/data/checkpoint hash 及关键 shape、单位和 frame。
#
# ## 实际产物
# 列出代码、数据、日志、报告和 demo 的绝对或仓库相对路径。
#
# ## 复现与验证证据
# 粘贴命令、退出码、关键输出、重算/重播证据；未执行项明确写“预期”。
#
# ## 失败、限制与补救
# 区分观察、推断和假设，给最小补救验收标准。
#
# ## 自测/答辩答案
# 逐题作答。
# ```
#
# ### 我的证据
#
# - 代码路径：【填写】
# - 配置路径：【填写】
# - 数据 / checkpoint / commit 或哈希：【填写】
# - 实际命令：【填写】
# - 退出码：【填写】
# - 关键输出：【填写】
# - 结果说明了什么：【填写】
# - 结果没有说明什么：【填写】
# - 失败现象与定位证据：【填写】
#
# ### VLA 约束
#
# | 约束 | 我的定义 |
# |---|---|
# | 图像布局、颜色顺序和范围 | 【填写】 |
# | 文本 token、padding 与 mask | 【填写】 |
# | 机器人状态各维含义 | 【填写】 |
# | 坐标系、长度和角度单位 | 【填写】 |
# | 动作空间及逐维定义 | 【填写】 |
# | observation/action 时间对齐 | 【填写】 |
# | 控制频率 / action chunk | 【填写】 |
# | 归一化及统计量来源 | 【填写】 |
# | 随机种子与数据划分 | 【填写】 |

# %% [markdown]
# ## Self-check：课程自测
#
# 1. 你能用两分钟解释整个系统吗？
# 2. 最可信与最弱的结论分别是什么？
# 3. 下一阶段最值得投入的数据或实验是什么？
#
# ---

# %% [markdown]
# ### 自测第 1 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 2 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ### 自测第 3 题作答
#
# 【双击此 Markdown 单元格，在这里填写答案。】

# %% [markdown]
# ## Help：排查、最低完成线与提高
#
# ### 常见错误
#
# - 把课程文件齐全等同能力通过。
# - 答辩只背论文，不能解释自己项目 shape/frame。
# - 未完成项没有可执行补救。
# - 先核对 spec/config/data/checkpoint/result hash、seed、stats key、动作单位/frame，再解释性能。
# - 不得把手写 outcome、mock OpenVLA 输出或预期命令包装成真实闭环/模型结果。
#
# ### 最低完成线
#
# 核心五项全部通过；可选大模型运行不要求，但 CPU/mock OpenVLA dry-run 与真实轻量闭环必须都有证据。 最低完成线仍须满足当天硬门槛。
#
# ### 可选提高
#
# 邀请同学按 REPRODUCE.md 做独立复现并记录 issue/修复。

# %% [markdown]
# ## Rubric
#
# | 评分项 | 分值 | 得分条件 |
# |---|---:|---|
# | spec/概念/shape | 20 | 输入、动作、闭环和版本合同准确 |
# | 实际项目产物 | 25 | 文件完整，来源与 hash 可追踪 |
# | 复现与验证 | 25 | 实际命令、退出码、重跑/重算证据充分 |
# | 泛化/失败/OpenVLA | 20 | 证据边界清楚，能诊断并解释接入 |
# | 复盘与答辩 | 10 | 限制诚实，回答自测并给补救 |
# | **总分** | **100** | **80 分通过** |
#
# 硬门槛：缺少真实可复现仿真闭环、数据/动作契约、OOD 失败分析，或 OpenVLA 理解/dry-run 证据；任何伪造均直接不通过。
#
# ### 提交前检查
#
# - [ ] 已逐项完成必做作业；
# - [ ] 已区分实际结果与预期结果；
# - [ ] 已保留代码输出、日志、表格或推理证据；
# - [ ] 已记录适用的 shape、坐标系、单位、动作和时间约定；
# - [ ] 已完成验证或明确写出无法执行的原因；
# - [ ] 已回答全部自测题；
# - [ ] 已记录仍不确定的点或失败案例。

# %% [markdown]
# ## Coach Review（学习者请勿填写）
#
# | 字段 | 验收结果 |
# |---|---|
# | 证据完整性 | 待验收 |
# | Rubric 得分 | /100 |
# | 门槛项 | 待验收 |
# | 当天状态 | 未提交 |
# | 具体缺口 |  |
# | 最小补救任务 |  |
# | 复验结果 |  |
# | 下一课程 |  |

# %% [markdown]
# ## Next Steps
#
# 完成后保存 Notebook，并把路径发到学习对话：
#
# `docs/vla-learning/notebooks/week-12/day-07.ipynb`
#
# 教练验收通过后才会更新 `PROGRESS.md`。
#
# [← Week 12 / Day 06](day-06.ipynb) · [本周 Notebook](README.md) · [课程正文](../../week-12/day-07.md) · [Notebook 总览 →](../README.md)
